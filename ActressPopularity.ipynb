# %%
import pandas as pd

file_path = 'ActressPopularityMovies.csv'
df_actor = pd.read_csv(file_path)

# %%
import matplotlib.pyplot as plt

# %%
df_actor
# Out:
#                primaryName  birthYear  deathYear  \
# 0           Julianne Moore     1960.0        NaN
# 1                Lin Shaye     1943.0        NaN
# 2     Candace Cameron Bure     1976.0        NaN
# 3             Cherie Chung     1960.0        NaN
# 4        Danielle Darrieux     1917.0     2017.0
# ...                    ...        ...        ...
# 1113             Miou-Miou     1950.0        NaN
# 1114          Silvia Pinal     1931.0        NaN
# 1115                Rohini     1969.0        NaN
# 1116        Brinke Stevens     1954.0        NaN
# 1117       Aparajita Adhya     1978.0        NaN
#
#                         primaryProfession  \
# 0             actress,producer,soundtrack
# 1             actress,producer,soundtrack
# 2             actress,producer,soundtrack
# 3                                 actress
# 4     actress,soundtrack,music_department
# ...                                   ...
# 1113                       actress,writer
# 1114          actress,producer,soundtrack
# 1115              actress,writer,director
# 1116              actress,producer,writer
# 1117                              actress
#
#                                 knownForTitles  average_popularity     nconst  \
# 0      tt0118749,tt2172584,tt0842926,tt0297884            6.308005  nm0000194
# 1      tt1591095,tt3195644,tt0308152,tt0129387            5.402225  nm0005417
# 2      tt3986586,tt0094006,tt0092359,tt0117191            5.478625  nm0121026
# 3      tt0096885,tt0101020,tt0093426,tt0125784            5.328565  nm0161193
# 4      tt0027951,tt0044314,tt0062873,tt0283832            5.812548  nm0201638
# ...                                        ...                 ...        ...
# 1113   tt0354899,tt0075946,tt0119773,tt0079091            5.681932  nm0591877
# 1114   tt0056732,tt0045090,tt0059719,tt0055601            5.970786  nm0683831
# 1115  tt0306098,tt7392212,tt5320514,tt20850406            6.093690  nm0737513
# 1116   tt0093991,tt0084695,tt4130510,tt7836680            5.087529  nm0828288
# 1117  tt0368969,tt15433876,tt8364356,tt1394310            6.160955  nm3533508
#
#                                       aggregated_genres
# 0     Comedy,Fantasy,Horror, Comedy,Drama,Mystery, C...
# 1     Thriller, Crime,Drama,Thriller, Action,Comedy,...
# 2     Thriller, Drama,Family,Romance, Comedy, Advent...
# 3     Comedy,Fantasy,Romance, Action, Comedy, Action...
# 4     Drama,Musical,Romance, Crime,Drama,History, Co...
# ...                                                 ...
# 1113  Adventure,Comedy,Romance, Comedy,Fantasy,Horro...
# 1114  Action,Drama,War, Comedy, Drama,Romance,Wester...
# 1115  Action,Thriller, Action, Crime,Drama,Thriller,...
# 1116  Thriller, Comedy,Fantasy,Horror, Comedy,Drama,...
# 1117  Comedy,Thriller, Drama,Musical,Romance, Drama,...
#
# [1118 rows x 8 columns]

# %%
df_Sorted=df_actor.sort_values(by='average_popularity', ascending=False)
df_Filtered= df_Sorted[df_Sorted['birthYear']!="\\N"]

# %%
df_Filtered['birthYear'] = pd.to_numeric(df_Filtered['birthYear'], errors='coerce')
df_Filtered= df_Filtered[df_Filtered['birthYear']>1950]
df_Filtered = df_Filtered[df_Filtered['average_popularity']>5.5]
df_Filtered
# Out:
#                primaryName  birthYear  deathYear  \
# 862   Mehazabien Chowdhury     1991.0        NaN
# 164                Madhavi     1962.0        NaN
# 1005    Scarlett Johansson     1984.0        NaN
# 330             Jaya Prada     1962.0        NaN
# 211              Jayasudha     1958.0        NaN
# ...                    ...        ...        ...
# 853    Lisa Maria Potthoff     1978.0        NaN
# 504      Karoline Eichhorn     1965.0        NaN
# 231            Traci Lords     1968.0        NaN
# 594        Monica Bellucci     1964.0        NaN
# 782      Pascale Bussières     1968.0        NaN
#
#                       primaryProfession  \
# 862                      actress,writer
# 164                             actress
# 1005        actress,soundtrack,producer
# 330   actress,music_department,producer
# 211                    actress,producer
# ...                                 ...
# 853                             actress
# 504                             actress
# 231         actress,soundtrack,producer
# 594         actress,soundtrack,producer
# 782           actress,writer,soundtrack
#
#                                   knownForTitles  average_popularity  \
# 862   tt20191212,tt21799612,tt28522135,tt2943024            6.827738
# 164      tt0257390,tt0378397,tt0082314,tt0230597            6.693339
# 1005     tt0162346,tt0335266,tt1798709,tt0848228            6.688214
# 330      tt0249963,tt0086231,tt0154154,tt0088099            6.685335
# 211      tt0374497,tt0187419,tt6417204,tt0251834            6.665964
# ...                                          ...                 ...
# 853     tt8648152,tt0382572,tt0780134,tt10375682            5.508577
# 504     tt0265188,tt0150703,tt5753856,tt23245972            5.507707
# 231      tt1984153,tt1007028,tt0120611,tt0099329            5.507658
# 594      tt0465602,tt0213847,tt0234215,tt0242653            5.506938
# 782      tt0114916,tt0396112,tt0148103,tt0292720            5.500397
#
#          nconst                                  aggregated_genres
# 862   nm5699416  Crime,Drama,Thriller, Comedy,Romance, Drama, R...
# 164   nm0534863  Action,Thriller, Action, Drama,Musical,Romance...
# 1005  nm0424060  Comedy,Drama,War, Comedy,Family,Fantasy, Comed...
# 330   nm0419685  Comedy,Fantasy,Romance, Action,Thriller, Crime...
# 211   nm0419707  Thriller, Action,Thriller, Action, Drama,Music...
# ...         ...                                                ...
# 853   nm0693383  Thriller, History, Adventure, Crime, Comedy, C...
# 504   nm0251526  Thriller, Crime,Drama,Thriller, Crime, Comedy,...
# 231   nm0000183  Thriller, Crime,Drama,Thriller, Comedy, Horror...
# 594   nm0000899  Thriller, Drama,Mystery,Romance, Crime,Drama,T...
# 782   nm0124481  Thriller, Comedy,Drama,Mystery, Crime,Drama,Th...
#
# [391 rows x 8 columns]

# %%
df_Filtered['aggregated_genres'] = df_Filtered['aggregated_genres'].str.replace(', ',',')

# %%
df_Filtered['aggregated_genres'] = df_Filtered['aggregated_genres'].str.split(',')
df_Filtered
# Out:
#                primaryName  birthYear  deathYear  \
# 862   Mehazabien Chowdhury     1991.0        NaN
# 164                Madhavi     1962.0        NaN
# 1005    Scarlett Johansson     1984.0        NaN
# 330             Jaya Prada     1962.0        NaN
# 211              Jayasudha     1958.0        NaN
# ...                    ...        ...        ...
# 853    Lisa Maria Potthoff     1978.0        NaN
# 504      Karoline Eichhorn     1965.0        NaN
# 231            Traci Lords     1968.0        NaN
# 594        Monica Bellucci     1964.0        NaN
# 782      Pascale Bussières     1968.0        NaN
#
#                       primaryProfession  \
# 862                      actress,writer
# 164                             actress
# 1005        actress,soundtrack,producer
# 330   actress,music_department,producer
# 211                    actress,producer
# ...                                 ...
# 853                             actress
# 504                             actress
# 231         actress,soundtrack,producer
# 594         actress,soundtrack,producer
# 782           actress,writer,soundtrack
#
#                                   knownForTitles  average_popularity  \
# 862   tt20191212,tt21799612,tt28522135,tt2943024            6.827738
# 164      tt0257390,tt0378397,tt0082314,tt0230597            6.693339
# 1005     tt0162346,tt0335266,tt1798709,tt0848228            6.688214
# 330      tt0249963,tt0086231,tt0154154,tt0088099            6.685335
# 211      tt0374497,tt0187419,tt6417204,tt0251834            6.665964
# ...                                          ...                 ...
# 853     tt8648152,tt0382572,tt0780134,tt10375682            5.508577
# 504     tt0265188,tt0150703,tt5753856,tt23245972            5.507707
# 231      tt1984153,tt1007028,tt0120611,tt0099329            5.507658
# 594      tt0465602,tt0213847,tt0234215,tt0242653            5.506938
# 782      tt0114916,tt0396112,tt0148103,tt0292720            5.500397
#
#          nconst                                  aggregated_genres
# 862   nm5699416  [Crime, Drama, Thriller, Comedy, Romance, Dram...
# 164   nm0534863  [Action, Thriller, Action, Drama, Musical, Rom...
# 1005  nm0424060  [Comedy, Drama, War, Comedy, Family, Fantasy, ...
# 330   nm0419685  [Comedy, Fantasy, Romance, Action, Thriller, C...
# 211   nm0419707  [Thriller, Action, Thriller, Action, Drama, Mu...
# ...         ...                                                ...
# 853   nm0693383  [Thriller, History, Adventure, Crime, Comedy, ...
# 504   nm0251526  [Thriller, Crime, Drama, Thriller, Crime, Come...
# 231   nm0000183  [Thriller, Crime, Drama, Thriller, Comedy, Hor...
# 594   nm0000899  [Thriller, Drama, Mystery, Romance, Crime, Dra...
# 782   nm0124481  [Thriller, Comedy, Drama, Mystery, Crime, Dram...
#
# [391 rows x 8 columns]

# %%
df_filtered_genres= df_Filtered[df_Filtered['aggregated_genres'].apply(lambda x: len(x) > 20)]

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_Filtered['primaryName'], df_Filtered['average_popularity'], s=df_Filtered['average_popularity']*20, c=df_Filtered['average_popularity'], cmap='viridis')

# Add labels and title
plt.xlabel('Actor')
plt.ylabel('Average Popularity')
plt.title('Bubble Chart of Actors and Average Popularity')

# Add colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Average Popularity', rotation=270, labelpad=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
df1=df_Filtered[:5]
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df1['primaryName'], df1['average_popularity'], s=df1['average_popularity']*20, c=df1['average_popularity'], cmap='viridis')

# Add labels and title
plt.xlabel('Actor')
plt.ylabel('Average Popularity')
plt.title('Bubble Chart of Actors and Average Popularity')

# Add colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Average Popularity', rotation=270, labelpad=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_filtered_genres= df_filtered_genres.drop(columns=['birthYear','deathYear','primaryProfession','nconst'])
# df_filteres_genres = df_Filtered.drop(columns=['birthYear','deathYear','primaryProfession','nconst'])

# %%
df_filtered_genres1=df_Filtered[:20]
df_exploded = df_filtered_genres1.explode('aggregated_genres')

df_filtered = df_exploded[~df_exploded['aggregated_genres'].str.strip().isin(['\\N', '\\\\N','Short','Sport','News','Talk-Show'])]

# Group by actor and genre, count occurrences
actor_genre_distribution = df_filtered.groupby(['primaryName', 'aggregated_genres']).size().reset_index(name='count')

# Calculate the total count of movies for each actor
actor_total_movies = actor_genre_distribution.groupby('primaryName')['count'].sum().reset_index(name='TotalMovies')

# Calculate the top 10 actors based on total movie count
top_10_actors = actor_total_movies.nlargest(10, 'TotalMovies')

# Merge the top 10 actors with the genre distribution data
top_10_genre_distribution = pd.merge(top_10_actors, actor_genre_distribution, on='primaryName')

# Pivot the data for plotting
pivot_df = top_10_genre_distribution.pivot(index='primaryName', columns='aggregated_genres', values='count').fillna(0)

# Plot the bar chart
pivot_df.plot(kind='bar', stacked=True)

plt.xlabel('Actress')
plt.ylabel('Number of Movies')
plt.title('Genre Distribution for Top 10 Actress')
plt.legend(title='Genre', bbox_to_anchor=(1, 1))
plt.show()
